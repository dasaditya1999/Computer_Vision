# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
image_pic = Image.open('Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/00-puppy.jpg')
# image_pic

# %%
type(image_pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_data_arr = np.array(image_pic)
# image_data_arr

# %%
image_data_arr.shape
# image_data_arr.nd
image_data_arr.shape
# Height = 1300
# Width = 1950
# No. of Channels = 3
# Out:
# (1300, 1950, 3)

# %%
# file = open('image_data.txt','w')
# file.write(str(image_data_arr))
# file.close()

# %%
# file = open('image_data.txt','r')
# file.read()

# %%
plt.imshow(image_data_arr)

# %%
red_image_arr = image_data_arr.copy()
# red_image_arr

# %%
plt.imshow(red_image_arr)

# %%
red_image_arr.shape
# Out:
# (1300, 1950, 3)

# %%
#Red image channel 0--->255
# 0--> No red pure black
# 255--> full pure red
plt.imshow(red_image_arr[:,:,0])

# %%
plt.imshow(red_image_arr[:,:,1])

# %%
plt.imshow(red_image_arr[:,:,2])

# %%
red_image_arr[:,:,1]=0
# red_image_arr[:,:,0]=0
plt.imshow(red_image_arr)
